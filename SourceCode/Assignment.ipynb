# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
# %pwd
# Out:
# '/gdrive'

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from scipy.stats import stats
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
os.chdir('/gdrive/My Drive')

# %%
file = pd.read_csv('SpotifyFeatures.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-39ee69540005> in <module>()
# ----> 1 file = pd.read_csv('SpotifyFeatures.csv')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
file.head()
# Out:
#    genre        artist_name  ... time_signature valence
# 0  Movie     Henri Salvador  ...            4/4   0.814
# 1  Movie  Martin & les fées  ...            4/4   0.816
# 2  Movie    Joseph Williams  ...            5/4   0.368
# 3  Movie     Henri Salvador  ...            4/4   0.227
# 4  Movie       Fabien Nataf  ...            4/4   0.390
#
# [5 rows x 18 columns]

# %%
len(file['track_name'])
# Out:
# 232725

# %%
file.groupby('genre').count()
# Out:
#                   artist_name  track_name  ...  time_signature  valence
# genre                                      ...
# A Capella                 119         119  ...             119      119
# Alternative              9263        9263  ...            9263     9263
# Anime                    8936        8936  ...            8936     8936
# Blues                    9023        9023  ...            9023     9023
# Children's Music         5403        5403  ...            5403     5403
# Children’s Music         9353        9353  ...            9353     9353
# Classical                9256        9256  ...            9256     9256
# Comedy                   9681        9681  ...            9681     9681
# Country                  8664        8664  ...            8664     8664
# Dance                    8701        8701  ...            8701     8701
# Electronic               9377        9377  ...            9377     9377
# ...

# %%
file1 = file.drop_duplicates(subset={'artist_name','track_name'},keep='first')

# %%
file1.head()
# Out:
#    genre        artist_name  ... time_signature valence
# 0  Movie     Henri Salvador  ...            4/4   0.814
# 1  Movie  Martin & les fées  ...            4/4   0.816
# 2  Movie    Joseph Williams  ...            5/4   0.368
# 3  Movie     Henri Salvador  ...            4/4   0.227
# 4  Movie       Fabien Nataf  ...            4/4   0.390
#
# [5 rows x 18 columns]

# %%
len(file1['track_name'])
# Out:
# 176514

# %%
file1.groupby('genre').count()
# Out:
#                   artist_name  track_name  ...  time_signature  valence
# genre                                      ...
# A Capella                 119         119  ...             119      119
# Alternative              9098        9098  ...            9098     9098
# Anime                    8935        8935  ...            8935     8935
# Blues                    8474        8474  ...            8474     8474
# Children's Music         5400        5400  ...            5400     5400
# Children’s Music         1269        1269  ...            1269     1269
# Classical                8703        8703  ...            8703     8703
# Comedy                   9674        9674  ...            9674     9674
# Country                  7382        7382  ...            7382     7382
# Dance                    7993        7993  ...            7993     7993
# Electronic               9150        9150  ...            9150     9150
# ...

# %%
file2 = file1[file1.genre!='Children’s Music']

# %%
file2.groupby('genre').count()
# Out:
#                   artist_name  track_name  ...  time_signature  valence
# genre                                      ...
# A Capella                 119         119  ...             119      119
# Alternative              9098        9098  ...            9098     9098
# Anime                    8935        8935  ...            8935     8935
# Blues                    8474        8474  ...            8474     8474
# Children's Music         5400        5400  ...            5400     5400
# Classical                8703        8703  ...            8703     8703
# Comedy                   9674        9674  ...            9674     9674
# Country                  7382        7382  ...            7382     7382
# Dance                    7993        7993  ...            7993     7993
# Electronic               9150        9150  ...            9150     9150
# Folk                     8050        8050  ...            8050     8050
# ...

# %%
genre = np.array(file2['genre'])

# %%
len(genre)
# Out:
# 175245

# %%
file2.groupby('genre').mean()
# Out:
#                   popularity  acousticness  ...       tempo   valence
# genre                                       ...
# A Capella           9.302521      0.829941  ...  111.518950  0.328724
# Alternative        50.260057      0.160088  ...  122.538745  0.448912
# Anime              24.256184      0.286874  ...  126.633144  0.441682
# Blues              33.637833      0.333101  ...  121.178216  0.580133
# Children's Music    4.239630      0.591723  ...  121.139381  0.676019
# Classical          29.311961      0.868529  ...  104.497091  0.215660
# Comedy             21.320240      0.793449  ...   98.215501  0.412648
# Country            44.265240      0.272280  ...  123.630546  0.534842
# Dance              57.356187      0.154678  ...  120.733181  0.517949
# Electronic         37.594098      0.119675  ...  125.914421  0.385310
# Folk               49.684845      0.484796  ...  118.600223  0.426952
# Hip-Hop            58.525762      0.173395  ...  122.048132  0.462287
# ...

# %%
dict = {5:"A Capella",13:"Alternative",10:"Anime",22:"Blues",25:"Children's Music",3:"Classical",
        7:"Comedy",21:"Country",20:"Dance",6:"Electronic",8:"Folk",15:"Hip-Hop",14:"Indie",18:"Jazz",12:"Movie",2:"Opera",17:"Pop",11:"R&B",9:"Rap",
        26:"Reggae",24:"Reggaeton",19:"Rock",23:"Ska",16:"Soul",1:"Soundtrack",4:"World"}

# %%
a = np.array(file1['genre'])

# %%
GenreRank = []
for i in range(len(a)):
  for j in range(1,len(dict)+1):
    if(a[i]==dict[j]):
      GenreRank.append(j)

# %%
len(GenreRank)
# Out:
# 175245

# %%
name = np.array(file2['artist_name'])

# %%
popularity = np.array(file2['popularity'])

# %%
sum = 0
artist_rank = []
for i in range(len(name)):
  for j in range(len(name)):
    if(name[i]==name[j]):
      sum = sum+popularity[j]
  artist_rank.append(sum)
  sum=0

# %%
len(artist_rank)
# Out:
# 175245

# %%
AR = []
count =0 
for i in range(len(artist_rank)):
  for j in range(len(artist_rank)):
    if(artist_rank[i]>=artist_rank[j]):
          count = count+1
  AR.append(count)
  count=0

# %%
len(AR)
# Out:
# 175245

# %%
file2['genre_rank'] = Gen

# %%
file2['artist_rank']=AR
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
file2.to_csv('work1.csv',index=False)

# %%
file2 = pd.read_csv(r'work1.csv')

# %%
file2.head()
# Out:
#    genre        artist_name  ... artist_sum artist_rank
# 0  Movie     Henri Salvador  ...       2205      120000
# 1  Movie  Martin & les fées  ...        132       13803
# 2  Movie    Joseph Williams  ...        354       33677
# 3  Movie     Henri Salvador  ...       2205      120000
# 4  Movie       Fabien Nataf  ...        174       17728
#
# [5 rows x 21 columns]

# %%
mode = np.array(file2['mode'])

# %%
file2.groupby('mode').mean()
# Out:
#        popularity  acousticness  ...   artist_sum   artist_rank
# mode                             ...
# Major   35.180841      0.421194  ...  2466.146440  87871.267828
# Minor   38.001995      0.375768  ...  2359.145403  87362.231686
#
# [2 rows x 14 columns]

# %%
mode_rank = []
for i in range(len(mode)):
  if(mode[i]=='Major'):
    mode_rank.append(2)
  else:
    mode_rank.append(1)

# %%
key = np.array(file2['key'])

# %%
file2.groupby('key').mean()
# Out:
#      popularity  acousticness  ...   artist_sum   artist_rank
# key                            ...
# A     35.895758      0.390437  ...  2421.779163  88367.596017
# A#    35.400253      0.440672  ...  2468.344233  86441.371018
# B     38.412406      0.319560  ...  2169.153074  86699.749529
# C     35.497260      0.423239  ...  2530.989038  88525.697500
# C#    38.245663      0.348445  ...  2309.681421  87835.784603
# D     35.073198      0.419096  ...  2560.068708  89063.302586
# D#    33.214237      0.565942  ...  2885.647616  89077.349002
# E     36.113371      0.410052  ...  2349.177401  87437.795254
# F     34.929705      0.461201  ...  2507.466981  86979.486005
# F#    37.950716      0.375725  ...  2125.634641  85273.279157
# G     35.245375      0.405296  ...  2486.948435  88113.799351
# G#    37.613585      0.385732  ...  2422.364556  87381.298889
#
# [12 rows x 14 columns]

# %%
dict = {10:"A",7:"A#",12:"B",4:"C",5:"C#",2:"D",1:"D#",3:"E",6:"F",11:"F#",9:"G",8:"G#"}

# %%
len(key)
# Out:
# 175245

# %%
key_rank = []
for i in range(len(key)):
  for j in range(1,len(dict)+1):
    if(key[i]==dict[j]):
      key_rank.append(j)

# %%
file2['mode_rank'] = mode_rank

# %%
file2['key_rank'] = key_rank

# %%
file2.head()
# Out:
#    genre        artist_name  ... mode_rank key_rank
# 0  Movie     Henri Salvador  ...         2        5
# 1  Movie  Martin & les fées  ...         1       11
# 2  Movie    Joseph Williams  ...         1        4
# 3  Movie     Henri Salvador  ...         2        5
# 4  Movie       Fabien Nataf  ...         2        6
#
# [5 rows x 23 columns]

# %% [markdown]
# **Saving this final file**

# %%
file2.head()
# Out:
#    genre        artist_name  ... key_rank valence
# 0  Movie     Henri Salvador  ...        5   0.814
# 1  Movie  Martin & les fées  ...       11   0.816
# 2  Movie    Joseph Williams  ...        4   0.368
# 3  Movie     Henri Salvador  ...        5   0.227
# 4  Movie       Fabien Nataf  ...        6   0.390
#
# [5 rows x 23 columns]

# %%
file2.groupby('time_signature').mean()
# Out:
#                 popularity  acousticness  ...  key_rank   valence
# time_signature                            ...
# 0/4              30.000000      0.818500  ...  4.833333  0.148067
# 1/4              25.979452      0.745421  ...  6.373288  0.309676
# 3/4              28.550920      0.700032  ...  6.312328  0.300733
# 4/4              37.590062      0.350366  ...  6.581935  0.479623
# 5/4              28.629470      0.698072  ...  6.449977  0.301697
#
# [5 rows x 16 columns]

# %%
a = np.array(file2['time_signature'])

# %%
len(a)
# Out:
# 175245

# %%
dict = {1:"0/4",4:"1/4",2:"3/4",5:"4/4",3:"5/4"}

# %%
time_key_rank = []
for i in range(len(a)):
  for j in range(1,len(dict)+1):
    if(a[i]==dict[j]):
      time_key_rank.append(j)

# %%
val = file2['valence']

# %%
file2.drop('valence',axis=1,inplace=True)

# %%
file2['time_key_rank']=time_key_rank

# %%
file2['valence']=val

# %%
file2.to_csv('FinalWorkFile.csv',index=False)

# %%
file2 = pd.read_csv('FinalWorkFile.csv')

# %%
file2.head()
# Out:
#    genre        artist_name  ... time_key_rank valence
# 0  Movie     Henri Salvador  ...             5   0.814
# 1  Movie  Martin & les fées  ...             5   0.816
# 2  Movie    Joseph Williams  ...             3   0.368
# 3  Movie     Henri Salvador  ...             5   0.227
# 4  Movie       Fabien Nataf  ...             5   0.390
#
# [5 rows x 24 columns]

# %%
file3 = file2.drop(labels={'genre','artist_name','track_name','track_id','key','mode','time_signature','artist_sum'},axis=1)

# %%
file3.head()
# Out:
#    popularity  acousticness  danceability  ...  key_rank  time_key_rank  valence
# 0           0         0.611         0.389  ...         5              5    0.814
# 1           1         0.246         0.590  ...        11              5    0.816
# 2           3         0.952         0.663  ...         4              3    0.368
# 3           0         0.703         0.240  ...         5              5    0.227
# 4           4         0.950         0.331  ...         6              5    0.390
#
# [5 rows x 16 columns]

# %% [markdown]
# **Scaling Data**

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
Max = MaxAbsScaler()

# %%
scale = file2[['popularity','duration_ms','loudness','tempo','genre_rank','artist_rank','mode_rank','key_rank','time_key_rank']]

# %%
scale.head()
# Out:
#    popularity  duration_ms  loudness  ...  mode_rank  key_rank  time_key_rank
# 0           0        99373    -1.828  ...          2         5              5
# 1           1       137373    -5.559  ...          1        11              5
# 2           3       170267   -13.879  ...          1         4              3
# 3           0       152427   -12.178  ...          2         5              5
# 4           4        82625   -21.150  ...          2         6              5
#
# [5 rows x 9 columns]

# %%
scale = Max.fit_transform(scale)

# %%
pdf = pd.DataFrame(scale)

# %%
pdf.head()
# Out:
#       0         1         2         3         4         5    6         7    8
# 0  0.00  0.017896 -0.034848  0.687390  0.461538  0.684756  1.0  0.416667  1.0
# 1  0.01  0.024739 -0.105973  0.716348  0.461538  0.078764  0.5  0.916667  1.0
# 2  0.03  0.030663 -0.264579  0.409579  0.461538  0.192171  0.5  0.333333  0.6
# 3  0.00  0.027450 -0.232152  0.707105  0.461538  0.684756  1.0  0.416667  1.0
# 4  0.04  0.014880 -0.403187  0.578733  0.461538  0.101161  1.0  0.500000  1.0

# %%
pdf.rename(columns={0:'popularity',1:'duration_ms',2:'loudness',3:'tempo',4:'genre_rank',5:'artist_rank',6:'mode_rank',7:'key_rank',8:'time_key_rank'},inplace=True)

# %%
pdf.head()
# Out:
#    popularity  duration_ms  loudness  ...  mode_rank  key_rank  time_key_rank
# 0        0.00     0.017896 -0.034848  ...        1.0  0.416667            1.0
# 1        0.01     0.024739 -0.105973  ...        0.5  0.916667            1.0
# 2        0.03     0.030663 -0.264579  ...        0.5  0.333333            0.6
# 3        0.00     0.027450 -0.232152  ...        1.0  0.416667            1.0
# 4        0.04     0.014880 -0.403187  ...        1.0  0.500000            1.0
#
# [5 rows x 9 columns]

# %%
file3[['popularity','duration_ms','loudness','tempo','genre_rank','artist_rank','mode_rank','key_rank','time_key_rank']] = pdf

# %%
file3.drop('artist_name',axis=1,inplace=True)

# %%
file3.head()
# Out:
#    popularity  acousticness  danceability  ...  key_rank  time_key_rank  valence
# 0        0.00         0.611         0.389  ...  0.416667            1.0    0.814
# 1        0.01         0.246         0.590  ...  0.916667            1.0    0.816
# 2        0.03         0.952         0.663  ...  0.333333            0.6    0.368
# 3        0.00         0.703         0.240  ...  0.416667            1.0    0.227
# 4        0.04         0.950         0.331  ...  0.500000            1.0    0.390
#
# [5 rows x 16 columns]

# %%
import statsmodels.formula.api as sm

# %%
model = sm.ols(formula='valence ~ popularity+acousticness+danceability+duration_ms+energy+instrumentalness+liveness+loudness+speechiness+tempo+genre_rank+artist_rank+mode_rank+key_rank', data=file3)
fitted = model.fit()
fitted.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                valence   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                 1.277e+04
# Date:                Tue, 14 Apr 2020   Prob (F-statistic):               0.00
# Time:                        19:38:40   Log-Likelihood:                 43573.
# No. Observations:              175245   AIC:                        -8.712e+04
# Df Residuals:                  175230   BIC:                        -8.696e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
file3.head()
# Out:
#    popularity  acousticness  danceability  ...  key_rank  time_key_rank  valence
# 0        0.00         0.611         0.389  ...  0.416667            1.0    0.814
# 1        0.01         0.246         0.590  ...  0.916667            1.0    0.816
# 2        0.03         0.952         0.663  ...  0.333333            0.6    0.368
# 3        0.00         0.703         0.240  ...  0.416667            1.0    0.227
# 4        0.04         0.950         0.331  ...  0.500000            1.0    0.390
#
# [5 rows x 16 columns]

# %%
pear = file3.corr(method='pearson')
pear
# Out:
#                   popularity  acousticness  ...  time_key_rank   valence
# popularity          1.000000     -0.358090  ...       0.184145  0.049416
# acousticness       -0.358090      1.000000  ...      -0.336918 -0.350385
# danceability        0.223960     -0.381784  ...       0.285905  0.588438
# duration_ms         0.019675      0.010192  ...       0.002212 -0.146256
# energy              0.232649     -0.729194  ...       0.272546  0.450585
# instrumentalness   -0.145358      0.304788  ...      -0.129687 -0.332712
# liveness           -0.161295      0.079333  ...      -0.110888  0.005370
# loudness            0.319722     -0.692750  ...       0.296059  0.428278
# speechiness        -0.160842      0.172355  ...      -0.179959  0.018534
# tempo               0.082721     -0.261201  ...       0.054426  0.159734
# genre_rank          0.142763     -0.416078  ...       0.236937  0.530627
# artist_rank         0.038190      0.066358  ...      -0.057988 -0.170472
# ...

# %%
popularity = np.array(file3['popularity'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['popularity'])
plt.show()

# %%
popularity = np.array(file3['acousticness'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['acousticness'])
plt.show()

# %%
popularity = np.array(file3['danceability'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['danceability'])
plt.show()

# %%
popularity = np.array(file3['duration_ms'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['duration_ms'])
plt.show()

# %%
popularity = np.array(file3['energy'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['energy'])
plt.show()

# %%
popularity = np.array(file3['instrumentalness'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['instrumentalness'])
plt.show()

# %%
popularity = np.array(file3['liveness'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['liveness'])
plt.show()

# %%
popularity = np.array(file3['loudness'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['loudness'])
plt.show()

# %%
popularity = np.array(file3['speechiness'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['speechiness'])
plt.show()

# %%
popularity = np.array(file3['tempo'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['tempo'])
plt.show()

# %%
popularity = np.array(file3['genre_rank'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['genre_rank'])
plt.show()

# %%
popularity = np.array(file3['artist_rank'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['artist_rank'])
plt.show()

# %%
popularity = np.array(file3['mode_rank'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['mode_rank'])
plt.show()

# %%
popularity = np.array(file3['key_rank'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['key_rank'])
plt.show()

# %%
popularity = np.array(file3['time_key_rank'])
popularity.sort()
mean = np.mean(popularity)
std = np.std(popularity)
pdf = stats.norm.pdf(popularity,mean,std)
plt.plot(popularity,pdf)
plt.show()

# %%
sb.boxplot(x=file3['time_key_rank'])
plt.show()

# %%
model = sm.ols(formula='valence ~ popularity+acousticness+danceability+duration_ms+energy+instrumentalness+speechiness+loudness+tempo+genre_rank', data=file3)
fitted = model.fit()
fitted.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                valence   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                 1.777e+04
# Date:                Tue, 14 Apr 2020   Prob (F-statistic):               0.00
# Time:                        20:12:29   Log-Likelihood:                 43319.
# No. Observations:              175245   AIC:                        -8.662e+04
# Df Residuals:                  175234   BIC:                        -8.650e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Droping based on graph and correlation**

# %%
file4 = file3.drop(labels={'time_key_rank','mode_rank','key_rank','artist_rank'},axis=1)

# %%
file4.head()
# Out:
#    popularity  acousticness  danceability  ...     tempo  genre_rank  valence
# 0        0.00         0.611         0.389  ...  0.687390    0.461538    0.814
# 1        0.01         0.246         0.590  ...  0.716348    0.461538    0.816
# 2        0.03         0.952         0.663  ...  0.409579    0.461538    0.368
# 3        0.00         0.703         0.240  ...  0.707105    0.461538    0.227
# 4        0.04         0.950         0.331  ...  0.578733    0.461538    0.390
#
# [5 rows x 12 columns]

# %%
pear = file4.corr(method='pearson')
pear
# Out:
#                   popularity  acousticness  ...  genre_rank   valence
# popularity          1.000000     -0.358090  ...    0.142763  0.049416
# acousticness       -0.358090      1.000000  ...   -0.416078 -0.350385
# danceability        0.223960     -0.381784  ...    0.491757  0.588438
# duration_ms         0.019675      0.010192  ...   -0.115415 -0.146256
# energy              0.232649     -0.729194  ...    0.376847  0.450585
# instrumentalness   -0.145358      0.304788  ...   -0.384775 -0.332712
# liveness           -0.161295      0.079333  ...   -0.084825  0.005370
# loudness            0.319722     -0.692750  ...    0.463803  0.428278
# speechiness        -0.160842      0.172355  ...   -0.100910  0.018534
# tempo               0.082721     -0.261201  ...    0.151133  0.159734
# genre_rank          0.142763     -0.416078  ...    1.000000  0.530627
# valence             0.049416     -0.350385  ...    0.530627  1.000000
#
# [12 rows x 12 columns]

# %%
model = sm.ols(formula='valence ~ popularity+acousticness+danceability+duration_ms+energy+instrumentalness+speechiness+loudness+tempo+genre_rank', data=file4)
fitted = model.fit()
fitted.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                valence   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                 1.777e+04
# Date:                Tue, 14 Apr 2020   Prob (F-statistic):               0.00
# Time:                        21:00:06   Log-Likelihood:                 43319.
# No. Observations:              175245   AIC:                        -8.662e+04
# Df Residuals:                  175234   BIC:                        -8.650e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
x = file4.iloc[:,0:11]
y = file4.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predict = lr.predict(x_test)

# %%
Y = np.array(y_test)

# %%
sse = 0
for i in range(len(predict)):
  sse = sse + (predict[i]-Y[i])**2
sse
# Out:
# 1254.4014051740994

# %%
from sklearn import metrics

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predict))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predict))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predict)))
# Out:
# Mean Absolute Error: 0.15112197503880692
# Mean Squared Error: 0.03578993423989533
# Root Mean Squared Error: 0.18918227781664784

# %%
a = np.array(file4['popularity'])

# %%
len(a)
# Out:
# 175245

# %%
z_scores = stats.zscore(file4)
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 2).all(axis=1)
file5 = file4[filtered_entries]

# %% [markdown]
# **As liveness do not have any effect we are removing it**

# %%
file5.head()
# Out:
#     popularity  acousticness  danceability  ...     tempo  genre_rank  valence
# 2         0.03         0.952         0.663  ...  0.409579    0.461538    0.368
# 4         0.04         0.950         0.331  ...  0.578733    0.461538    0.390
# 7         0.15         0.939         0.416  ...  0.398624    0.461538    0.274
# 9         0.10         0.319         0.598  ...  0.566053    0.461538    0.718
# 12        0.04         0.215         0.680  ...  0.452963    0.461538    0.433
#
# [5 rows x 12 columns]

# %%
len(np.array(file5['popularity']))
# Out:
# 117052

# %%
temp = file5.drop('liveness',axis=1)

# %%
model = sm.ols(formula='valence ~ popularity+acousticness+danceability+duration_ms+energy+instrumentalness+speechiness+loudness+tempo+genre_rank', data=temp)
fitted = model.fit()
fitted.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                valence   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     9354.
# Date:                Tue, 14 Apr 2020   Prob (F-statistic):               0.00
# Time:                        21:12:10   Log-Likelihood:                 29018.
# No. Observations:              117052   AIC:                        -5.801e+04
# Df Residuals:                  117041   BIC:                        -5.791e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
pear = file5.corr(method='pearson')
pear
# Out:
#                   popularity  acousticness  ...  genre_rank   valence
# popularity          1.000000     -0.226078  ...    0.079947 -0.002428
# acousticness       -0.226078      1.000000  ...   -0.274029 -0.250916
# danceability        0.221345     -0.264741  ...    0.375001  0.490934
# duration_ms         0.051895     -0.064412  ...   -0.129867 -0.165176
# energy              0.141331     -0.747889  ...    0.276119  0.387661
# instrumentalness   -0.114106      0.103018  ...   -0.222595 -0.151770
# liveness           -0.050365     -0.083542  ...   -0.002094  0.034933
# loudness            0.243218     -0.662116  ...    0.291822  0.284215
# speechiness         0.084673     -0.132854  ...    0.101996  0.082419
# tempo               0.030458     -0.175385  ...    0.031188  0.066657
# genre_rank          0.079947     -0.274029  ...    1.000000  0.444215
# valence            -0.002428     -0.250916  ...    0.444215  1.000000
#
# [12 rows x 12 columns]

# %%
x = file5.iloc[:,0:11]
y = file5.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predict = lr.predict(x_test)

# %%
Y = np.array(y_test)

# %%
sse = 0
for i in range(len(predict)):
  sse = sse + (predict[i]-Y[i])**2
sse
# Out:
# 828.617046493856

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predict))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predict))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predict)))
# Out:
# Mean Absolute Error: 0.15217076000676416
# Mean Squared Error: 0.03539434652487534
# Root Mean Squared Error: 0.18813385268174182

# %% [markdown]
# **Applying PCA on high co-related task**

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)

# %%
x = file5[['acousticness','energy','loudness']]

# %%
principalcomponent = pca.fit_transform(x)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.87462896, 0.11415785, 0.01121319])

# %%
principal = pd.DataFrame(principalcomponent)

# %%
principal.head()
# Out:
#           0         1         2
# 0  0.811183  0.025853 -0.027041
# 1  0.779375 -0.019595  0.130994
# 2  0.708593 -0.094361 -0.082443
# 3 -0.043038 -0.083648  0.017158
# 4 -0.069486  0.059266 -0.009675

# %%
a = np.array(principal[0])

# %%
a
# Out:
# array([ 0.81118328,  0.77937521,  0.70859259, ..., -0.109063  ,
#        -0.2664047 , -0.09592482])

# %%
file6 = file5.drop('liveness',axis=1)

# %%
file6.drop(labels={'energy','loudness'},axis=1,inplace=True)

# %%
file6.head()
# Out:
#     popularity  acousticness  danceability  ...     tempo  genre_rank  valence
# 2         0.03         0.952         0.663  ...  0.409579    0.461538    0.368
# 4         0.04         0.950         0.331  ...  0.578733    0.461538    0.390
# 7         0.15         0.939         0.416  ...  0.398624    0.461538    0.274
# 9         0.10         0.319         0.598  ...  0.566053    0.461538    0.718
# 12        0.04         0.215         0.680  ...  0.452963    0.461538    0.433
#
# [5 rows x 9 columns]

# %%
file6.rename(columns={'acousticness':'AEL'},inplace=True)

# %%
file6.head()
# Out:
#     popularity       AEL  danceability  ...     tempo  genre_rank  valence
# 2         0.03  0.811183         0.663  ...  0.409579    0.461538    0.368
# 4         0.04  0.779375         0.331  ...  0.578733    0.461538    0.390
# 7         0.15  0.708593         0.416  ...  0.398624    0.461538    0.274
# 9         0.10 -0.043038         0.598  ...  0.566053    0.461538    0.718
# 12        0.04 -0.069486         0.680  ...  0.452963    0.461538    0.433
#
# [5 rows x 9 columns]

# %%
model = sm.ols(formula='valence ~ popularity+AEL+danceability+duration_ms+instrumentalness+speechiness+tempo+genre_rank', data=file6)
fitted = model.fit()
fitted.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                valence   R-squared:                       0.374
# Model:                            OLS   Adj. R-squared:                  0.374
# Method:                 Least Squares   F-statistic:                     8745.
# Date:                Tue, 14 Apr 2020   Prob (F-statistic):               0.00
# Time:                        21:09:26   Log-Likelihood:                 22067.
# No. Observations:              117052   AIC:                        -4.412e+04
# Df Residuals:                  117043   BIC:                        -4.403e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
pear = file6.corr(method='pearson')
pear
# Out:
#                   popularity       AEL  ...  genre_rank   valence
# popularity          1.000000 -0.212358  ...    0.079947 -0.002428
# AEL                -0.212358  1.000000  ...   -0.293933 -0.316832
# danceability        0.221345 -0.258949  ...    0.375001  0.490934
# duration_ms         0.051895 -0.043842  ...   -0.129867 -0.165176
# instrumentalness   -0.114106  0.121291  ...   -0.222595 -0.151770
# speechiness         0.084673 -0.149790  ...    0.101996  0.082419
# tempo               0.030458 -0.195002  ...    0.031188  0.066657
# genre_rank          0.079947 -0.293933  ...    1.000000  0.444215
# valence            -0.002428 -0.316832  ...    0.444215  1.000000
#
# [9 rows x 9 columns]

# %%
x = file6.iloc[:,0:8]
y = file6.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predict = lr.predict(x_test)

# %%
Y = np.array(y_test)

# %%
sse = 0
for i in range(len(predict)):
  sse = sse + (predict[i]-Y[i])**2
sse
# Out:
# 950.1684977013082

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predict))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predict))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predict)))
# Out:
# Mean Absolute Error: 0.1637688382400231
# Mean Squared Error: 0.040586412272064984
# Root Mean Squared Error: 0.20146069659381452
